# %% [markdown]
# # Munging tabular data
#
# We're going to go through how to munge tabular data in more detail (and _slowly_). The aim is for you to get comfortable with the tools we're using:
#
# - [pandas](pandas.pydata.org) for data handling (our dataframe library)
# - [seaborn](seaborn.pydata.org) for _nice_ data visualization
# - [scipy](scipy.org) for scientific libraries (particularly `scipy.stats` which we'll use for fitting some more unusual probability distributions), and
# - [statsmodels](statsmodels.org) which gives us some more expressive curve fitting approaches
#
# The other aim is to get familiar with code-sharing workflows - so we will be doing pair programming for the duration of the day! _You will probably want to take a moment to look at the documentation of the libraries above - especially pandas_
#
# The other useful resource is Stack Overflow - if you have a question that sounds like 'how do I do {x}' then someone will probably have answered it on SO. Questions are also tagged by library so if you have a particular pandas question you can do something like going to https://stackoverflow.com/questions/tagged/pandas (just replace the 'pandas' in the URL with whatever library you're trying to use.
#
# Generally answers on SO are probably a lot closer to getting you up and running than the documentation. Once you get used to the library then the documentation is generally a quicker reference. We will cover strategies for getting help in class.
#
# ## Git links
#
# We will be working through using GitHub and GitKraken to share code between pairs. We will go through all the workflow in detail in class but here are some useful links for reference:
#
# - GitKraken interface basics: https://support.gitkraken.com/start-here/interface
# - Staging and committing (save current state -> local history): https://support.gitkraken.com/working-with-commits/commits
# - Pushing and pulling (sync local history <-> GitHub history): https://support.gitkraken.com/working-with-repositories/pushing-and-pulling
# - Forking and pull requests (request to sync your GitHub history <-> someone else's history - requires a _review_):
#   - https://help.github.com/articles/about-forks/
#   - https://help.github.com/articles/creating-a-pull-request-from-a-fork/
#
# ## Step 1: Reading my data
#
# In pairs work out how to read your data into a pandas dataframe.
#
# If you have your own tabular data please start using it here. If not, use the ATCO dataset from last week.

# %%
# your code goes here
import pandas as pd

# %%
import os

data_folder = os.path.abspath('../data')
fault_data_file = os.path.join(data_folder, 'Mains Faults Data_SAP_2010-2016.xlsx')
age_data_file = os.path.join(data_folder, 'Mains_Age_Profile_Estimation 250516.xlsm')
fault_data_file
# Out:
# 'C:\\Users\\Oliver.Mapeto\\Documents\\03_week_data\\02-getting-to-know-the-tools\\data\\Mains Faults Data_SAP_2010-2016.xlsx'

# %%
geochem_df = pd.read_csv('../data/test_data_v2.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
geochem_df
# Out:
#       compid          dhid        midx         midy     midz        topx  \
# 0       COMP        RH0019  801774.902  7514841.624  449.210  801774.902
# 1       COMP        RH0019  801774.902  7514841.624  447.210  801774.902
# 2       COMP        RH0019  801774.902  7514841.624  445.210  801774.902
# 3       COMP        RH0019  801774.902  7514841.624  441.210  801774.902
# 4       COMP        RH0020  802275.996  7514295.708  448.780  802275.996
# 5       COMP        RH0020  802275.996  7514295.708  444.780  802275.996
# 6       COMP        RH0020  802275.996  7514295.708  428.780  802275.996
# 7       COMP        RH0020  802275.996  7514295.708  426.780  802275.996
# 8       COMP        RH0020  802275.996  7514295.708  424.780  802275.996
# 9       COMP        RH0020  802275.996  7514295.708  422.780  802275.996
# 10      COMP        RH0020  802275.996  7514295.708  420.780  802275.996
# 11      COMP        RH0020  802275.996  7514295.708  418.780  802275.996
# 12      COMP        RH0020  802275.996  7514295.708  416.780  802275.996
# ONAM     3.292170  0.055719  0.607362   3.816851  0.057021  0.165034
# SONAM    4.498553  0.062257  0.752763   7.549737  0.028763  0.226388
# TNAM     2.542678  0.070030  0.417944   7.951998  0.034327  0.143318
#
#               cao        mgo       k2o  ore
# geocod
# ALU      0.226865   0.366500  0.605267  0.0
# CC      15.525735  11.333358  0.313279  0.0
# CLA_L    0.144762   0.102857  0.056143  0.0
# CLA_M    0.161698   0.174906  0.082679  0.0
# CLA_U    0.147273   0.171636  0.180873  0.0
# DID_L    0.072281   0.122642  0.074654  0.0
# DID_U    0.085823   0.110923  0.038212  0.0
# DIW_L    0.114537   0.210950  0.148922  0.0
# DIW_M    0.132881   0.182829  0.106257  0.0
# DIW_U    0.169852   0.248476  0.160750  0.0
# HNAM     0.122596   0.109038  0.075942  0.0
# JER      3.135591   2.680624  2.304068  0.0
# NAM      0.087117   0.172252  0.218134  0.0
# ONAM     0.127957   0.290723  0.173123  0.0
# SONAM    0.058191   0.119967  0.099595  0.0
# TNAM     0.047546   0.082778  0.043738  0.0
#
# [16 rows x 25 columns]

# %%
# %matplotlib inline
import seaborn
seaborn.set()

# %%
seaborn.distplot(geochem_df.fe)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
seaborn.kdeplot(geochem_df.fe)

# %%
def my_function(a, b):
    mysum = a + b
    print('hello from my_function')
    print(f'my sum is {mysum}')

# %%
seaborn.jointplot('fe', 'geocod', geochem_df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-c182f5b1f80a> in <module>()
# ----> 1 seaborn.jointplot('fe', 'geocod', geochem_df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2249         marginal_kws.setdefault("kde", False)
#    2250         marginal_kws.setdefault("color", color)
# -> 2251         grid.plot_marginals(distplot, **marginal_kws)
#    2252
#    2253     elif kind.startswith("hex"):
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1782         kwargs["vertical"] = True
#    1783         plt.sca(self.ax_marg_y)
# -> 1784         func(self.y, **kwargs)
#    1785
#    1786         return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     210     if hist:
#     211         if bins is None:
# --> 212             bins = min(_freedman_diaconis_bins(a), 50)
#     213         hist_kws.setdefault("alpha", 0.4)
#     214         hist_kws.setdefault("normed", norm_hist)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      29     if len(a) < 2:
#      30         return 1
# ---> 31     h = 2 * iqr(a) / (len(a) ** (1 / 3))
#      32     # fall back to sqrt(a) bins if iqr is 0
#      33     if h == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py in iqr(a)
#     346     """Calculate the IQR for an array of numbers."""
#     347     a = np.asarray(a)
# --> 348     q1 = stats.scoreatpercentile(a, 25)
#     349     q3 = stats.scoreatpercentile(a, 75)
#     350     return q3 - q1
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in scoreatpercentile(a, per, limit, interpolation_method, axis)
#    1668         axis = 0
#    1669
# -> 1670     return _compute_qth_percentile(sorted, per, interpolation_method, axis)
#    1671
#    1672
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in _compute_qth_percentile(sorted, per, interpolation_method, axis)
#    1711
#    1712     # Use np.add.reduce (== np.sum but a little faster) to coerce data type
# -> 1713     return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
#    1714
#    1715
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %%
seaborn.jointplot('fe', 'geocod', geochem_df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-c182f5b1f80a> in <module>()
# ----> 1 seaborn.jointplot('fe', 'geocod', geochem_df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2249         marginal_kws.setdefault("kde", False)
#    2250         marginal_kws.setdefault("color", color)
# -> 2251         grid.plot_marginals(distplot, **marginal_kws)
#    2252
#    2253     elif kind.startswith("hex"):
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1782         kwargs["vertical"] = True
#    1783         plt.sca(self.ax_marg_y)
# -> 1784         func(self.y, **kwargs)
#    1785
#    1786         return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     210     if hist:
#     211         if bins is None:
# --> 212             bins = min(_freedman_diaconis_bins(a), 50)
#     213         hist_kws.setdefault("alpha", 0.4)
#     214         hist_kws.setdefault("normed", norm_hist)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      29     if len(a) < 2:
#      30         return 1
# ---> 31     h = 2 * iqr(a) / (len(a) ** (1 / 3))
#      32     # fall back to sqrt(a) bins if iqr is 0
#      33     if h == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py in iqr(a)
#     346     """Calculate the IQR for an array of numbers."""
#     347     a = np.asarray(a)
# --> 348     q1 = stats.scoreatpercentile(a, 25)
#     349     q3 = stats.scoreatpercentile(a, 75)
#     350     return q3 - q1
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in scoreatpercentile(a, per, limit, interpolation_method, axis)
#    1668         axis = 0
#    1669
# -> 1670     return _compute_qth_percentile(sorted, per, interpolation_method, axis)
#    1671
#    1672
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in _compute_qth_percentile(sorted, per, interpolation_method, axis)
#    1711
#    1712     # Use np.add.reduce (== np.sum but a little faster) to coerce data type
# -> 1713     return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
#    1714
#    1715
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %%
geochem_df.groupby('geocod').mean()['fe']
# Out:
# geocod
# ALU      26.487068
# CC        9.198603
# CLA_L    26.057619
# CLA_M    28.842453
# CLA_U    34.183455
# DID_L    53.186917
# DID_U    51.374158
# DIW_L    31.742613
# DIW_M    40.620135
# DIW_U    41.226358
# HNAM     49.924423
# JER      16.772541
# NAM      26.073581
# ONAM     58.921064
# SONAM    52.570888
# TNAM     58.481285
# Name: fe, dtype: float64

# %%
geochem_df.groupby('geocod').mean()['sio2']
# Out:
# geocod
# ALU      43.082765
# CC       28.006838
# CLA_L    30.037143
# CLA_M    24.863208
# CLA_U    24.911636
# DID_L     6.948227
# DID_U     8.328431
# DIW_L    22.819644
# DIW_M    16.365744
# DIW_U    19.204317
# HNAM     16.131154
# JER      46.454271
# NAM      53.480791
# ONAM      6.528000
# SONAM    10.924211
# TNAM      4.689362
# Name: sio2, dtype: float64

# %%
geochem_df.groupby('geocod').mean()['al2o3']
# Out:
# geocod
# ALU      10.836010
# CC        3.968358
# CLA_L    20.737143
# CLA_M    20.931321
# CLA_U    15.717455
# DID_L     5.710412
# DID_U     6.493202
# DIW_L    17.922969
# DIW_M    12.724957
# DIW_U    10.756772
# HNAM      4.246058
# JER       9.360481
# NAM       3.830671
# ONAM      3.292170
# SONAM     4.498553
# TNAM      2.542678
# Name: al2o3, dtype: float64

# %%
seaborn.jointplot('sio2', 'fe', geochem_df, kind='hex')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
my_function(1, 2)
# Out:
# hello from my_function
# my sum is 3

# %%
for a in range(10):
    for b in range(10):
        my_function(a, b)
# Out:
# hello from my_function
# my sum is 0
# hello from my_function
# my sum is 1
# hello from my_function
# my sum is 2
# hello from my_function
# my sum is 3
# hello from my_function
# my sum is 4
# hello from my_function
# my sum is 5
# hello from my_function
# my sum is 6
# hello from my_function
# my sum is 7
# hello from my_function
# my sum is 8
# hello from my_function
# my sum is 9
# hello from my_function
# my sum is 1
# hello from my_function
# my sum is 2
# hello from my_function
# my sum is 3
# hello from my_function
# my sum is 4
# hello from my_function
# my sum is 5
# hello from my_function
# my sum is 6
# hello from my_function
# my sum is 7
# hello from my_function
# my sum is 8
# hello from my_function
# my sum is 9
# hello from my_function
# my sum is 10
# hello from my_function
# my sum is 2
# hello from my_function
# my sum is 3
# hello from my_function
# my sum is 4
# hello from my_function
# my sum is 5
# hello from my_function
# my sum is 6
# hello from my_function
# my sum is 7
# hello from my_function
# my sum is 8
# hello from my_function
# my sum is 9
# hello from my_function
# my sum is 10
# hello from my_function
# my sum is 11
# hello from my_function
# my sum is 3
# hello from my_function
# my sum is 4
# hello from my_function
# my sum is 5
# hello from my_function
# my sum is 6
# hello from my_function
# my sum is 7
# hello from my_function
# my sum is 8
# hello from my_function
# my sum is 9
# hello from my_function
# my sum is 10
# hello from my_function
# my sum is 11
# hello from my_function
# my sum is 12
# hello from my_function
# my sum is 4
# hello from my_function
# my sum is 5
# hello from my_function
# my sum is 6
# hello from my_function
# my sum is 7
# hello from my_function
# my sum is 8
# hello from my_function
# my sum is 9
# hello from my_function
# my sum is 10
# hello from my_function
# my sum is 11
# hello from my_function
# my sum is 12
# hello from my_function
# my sum is 13
# hello from my_function
# my sum is 5
# hello from my_function
# my sum is 6
# hello from my_function
# my sum is 7
# hello from my_function
# my sum is 8
# hello from my_function
# my sum is 9
# hello from my_function
# my sum is 10
# hello from my_function
# my sum is 11
# hello from my_function
# my sum is 12
# hello from my_function
# my sum is 13
# hello from my_function
# my sum is 14
# hello from my_function
# my sum is 6
# hello from my_function
# my sum is 7
# hello from my_function
# my sum is 8
# hello from my_function
# my sum is 9
# hello from my_function
# my sum is 10
# hello from my_function
# my sum is 11
# hello from my_function
# my sum is 12
# hello from my_function
# my sum is 13
# hello from my_function
# my sum is 14
# hello from my_function
# my sum is 15
# hello from my_function
# my sum is 7
# hello from my_function
# my sum is 8
# hello from my_function
# my sum is 9
# hello from my_function
# my sum is 10
# hello from my_function
# my sum is 11
# hello from my_function
# my sum is 12
# hello from my_function
# my sum is 13
# hello from my_function
# my sum is 14
# hello from my_function
# my sum is 15
# hello from my_function
# my sum is 16
# hello from my_function
# my sum is 8
# hello from my_function
# my sum is 9
# hello from my_function
# my sum is 10
# hello from my_function
# my sum is 11
# hello from my_function
# my sum is 12
# hello from my_function
# my sum is 13
# hello from my_function
# my sum is 14
# hello from my_function
# my sum is 15
# hello from my_function
# my sum is 16
# hello from my_function
# my sum is 17
# hello from my_function
# my sum is 9
# hello from my_function
# my sum is 10
# hello from my_function
# my sum is 11
# hello from my_function
# my sum is 12
# hello from my_function
# my sum is 13
# hello from my_function
# my sum is 14
# hello from my_function
# my sum is 15
# hello from my_function
# my sum is 16
# hello from my_function
# my sum is 17
# hello from my_function
# my sum is 18

# %% [markdown]
# Once you've worked this out in the Jupyter notebook, transfer your code to a Python script (say a function called `load_data` in a file called `munging.py` in the same directory as the notebooks - you can create a text file in the Jupyter notebook home screen). Then try importing your load function with
#
# ```python
# from munging import load_data
#
# df = load_data('path/to/datafile')
# ```

# %%
postcode_df = pd.read_csv('C:\\Users\\Oliver.Mapeto\\Documents\\03_week_data\\02-getting-to-know-the-tools\\data\\australian_postcodes.csv')

# %% [markdown]
# Next work out how to access a column within your dataframe.
#
# - How can you list all the column names?
# - There are two ways to access columns by name - try to find out what both of these are.
# - There's also methods to access columns by number - try to do this as well
#
# Next look at how to access rows - both using labels and numbers.

# %%
postcode_df
# Out:
#        postcode            locality state        long        lat  \
# 0             0                 NaN   NaN    0.000000   0.000000
# 1           200                 ANU   ACT    0.000000   0.000000
# 2           221              BARTON   ACT    0.000000   0.000000
# 3           800              DARWIN    NT  130.836680 -12.458684
# 4           801              DARWIN    NT    0.000000   0.000000
# 5           804               PARAP    NT    0.000000   0.000000
# 6           810               ALAWA    NT  130.866242 -12.381806
# 7           810             BRINKIN    NT  130.866242 -12.381806
# 8           810           CASUARINA    NT  130.866242 -12.381806
# 9           810       COCONUT GROVE    NT  130.866242 -12.381806
# 10          810             JINGILI    NT  130.866242 -12.381806
# 11          810           LEE POINT    NT  130.866242 -12.381806
# 12          810             MILLNER    NT  130.866242 -12.381806
# 13          810                MOIL    NT  130.866242 -12.381806
# 14          810              NAKARA    NT  130.866242 -12.381806
# 15          810          NIGHTCLIFF    NT  130.866242 -12.381806
# 16          810         RAPID CREEK    NT  130.866242 -12.381806
# 17          810                TIWI    NT  130.866242 -12.381806
# 18          810             WAGAMAN    NT  130.866242 -12.381806
# 19          810             WANGURI    NT  130.866242 -12.381806
# 20          811           CASUARINA    NT    0.000000   0.000000
# 21          812               ANULA    NT  130.916098 -12.404778
# 22          812              KARAMA    NT  130.916098 -12.404778
# 23          812             LEANYER    NT  130.916098 -12.404778
# 24          812               MALAK    NT  130.916098 -12.404778
# 25          812             MARRARA    NT  130.916098 -12.404778
# 26          812          NORTHLAKES    NT  130.916098 -12.404778
# 27          812           SANDERSON    NT  130.916098 -12.404778
# 28          812   WOODLEIGH GARDENS    NT  130.916098 -12.404778
# 29          812              WULAGI    NT  130.916098 -12.404778
# ...         ...                 ...   ...         ...        ...
# 16644       880           NHULUNBUY    NT  136.783889 -12.184210
# 16645       881           NHULUNBUY    NT  136.783889 -12.184210
# 16646       886              JABIRU    NT  130.893097 -12.381028
# 16647      8865     SOUTH MELBOURNE   VIC    0.000000   0.000000
# 16648      8873      PORT MELBOURNE   VIC    0.000000   0.000000
# 16649      9000            BRISBANE   QLD    0.000000   0.000000
# 16650      9001            BRISBANE   QLD    0.000000   0.000000
# 16651      9002            BRISBANE   QLD    0.000000   0.000000
# 16652      9003            BRISBANE   QLD    0.000000   0.000000
# 16653      9005            BRISBANE   QLD    0.000000   0.000000
# 16654      9007            BRISBANE   QLD    0.000000   0.000000
# 16655      9008            BRISBANE   QLD    0.000000   0.000000
# 16656      9009            BRISBANE   QLD    0.000000   0.000000
# 16657      9010            BRISBANE   QLD    0.000000   0.000000
# 16658      9013            BRISBANE   QLD    0.000000   0.000000
# 16659      9015            BRISBANE   QLD    0.000000   0.000000
# 16660      9016  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16661      9017  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16662      9018  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16663      9019  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16664      9020            BRISBANE   QLD    0.000000   0.000000
# 16665      9021  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16666      9022  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16667      9023  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16668       906           WINNELLIE    NT  130.882367 -12.426641
# 16669       907           WINNELLIE    NT  130.882367 -12.426641
# 16670      9464        NORTHGATE MC   QLD    0.000000   0.000000
# 16671      9726       GOLD COAST MC   QLD    0.000000   0.000000
# 16672      9728       GOLD COAST MC   QLD    0.000000   0.000000
# 16673      9729       GOLD COAST MC   QLD    0.000000   0.000000
#
#                        dc               type
# 0                     NaN                NaN
# 1                     NaN                NaN
# 2                     NaN                NaN
# 3                     NaN                NaN
# 4                     NaN                NaN
# 5                     NaN                NaN
# 6                     NaN                NaN
# 7                     NaN                NaN
# 8                     NaN                NaN
# 9                     NaN                NaN
# 10                    NaN                NaN
# 11                    NaN                NaN
# 12                    NaN                NaN
# 13                    NaN                NaN
# 14                    NaN                NaN
# 15                    NaN                NaN
# 16                    NaN                NaN
# 17                    NaN                NaN
# 18                    NaN                NaN
# 19                    NaN                NaN
# 20                    NaN                NaN
# 21                    NaN                NaN
# 22                    NaN                NaN
# 23                    NaN                NaN
# 24                    NaN                NaN
# 25                    NaN                NaN
# 26                    NaN                NaN
# 27                    NaN                NaN
# 28                    NaN                NaN
# 29                    NaN                NaN
# ...                   ...                ...
# 16644           NHULUNBUY      Delivery Area
# 16645           NHULUNBUY  Post Office Boxes
# 16646              JABIRU      Delivery Area
# 16647  SOUTH MELBOURNE DC  Post Office Boxes
# 16648  SOUTH MELBOURNE DC  Post Office Boxes
# 16649  CITY DC - BRISBANE                LVR
# 16650  CITY DC - BRISBANE                LVR
# 16651  CITY DC - BRISBANE                LVR
# 16652                 NaN                NaN
# 16653  CITY DC - BRISBANE                LVR
# 16654  CITY DC - BRISBANE                LVR
# 16655  CITY DC - BRISBANE                LVR
# 16656  CITY DC - BRISBANE                LVR
# 16657  CITY DC - BRISBANE                LVR
# 16658  CITY DC - BRISBANE                LVR
# 16659  CITY DC - BRISBANE                LVR
# 16660                 NaN                NaN
# 16661                 NaN                NaN
# 16662                 NaN                NaN
# 16663                 NaN                NaN
# 16664  CITY DC - BRISBANE                LVR
# 16665                 NaN                NaN
# 16666                 NaN                NaN
# 16667                 NaN                NaN
# 16668           DARWIN MC                LVR
# 16669           DARWIN MC                LVR
# 16670                 NaN                NaN
# 16671                 NaN                NaN
# 16672                 NaN                NaN
# 16673                 NaN                NaN
#
# [16674 rows x 7 columns]

# %% [markdown]
# To access records efficiently pandas can construct an index for your data. Find out how you set the index on your dataframe and pick a useful column (i.e. one that has a unique value for each record and can be sorted) and set this as the index.
#
# Try selecting data using your index (especially if you have a timeseries index)

# %% [markdown]
# If you get through this quickly, take a look at the [other data formats that pandas is able to read](http://pandas.pydata.org/pandas-docs/stable/api.html#input-output) and find out about these online - we can have a discussion about when you might like to use them. Pay particular attention to [`pandas.read_sql`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql.html#pandas.read_sql) as that's pretty useful for ripping data from databases.
#
# Go to [data.gov.au](https://data.gov.au) and find some other data in different formats to read and try reading it.
#
# ## Step 2: What's in my data?
#
# First find the documentation in pandas on datatypes!
#
# Work through the columns in your dataset and assign them to the correct datatype.

# %%
import os

data_file = os.path.abspath('../data/australian_postcodes.csv')
data_file
# Out:
# 'C:\\Users\\Oliver.Mapeto\\Documents\\03_week_data\\02-getting-to-know-the-tools\\data\\australian_postcodes.csv'

# %%
pd.read_csv('C:\\Users\\Oliver.Mapeto\\Documents\\03_week_data\\02-getting-to-know-the-tools\\data\\australian_postcodes.csv')
# Out:
#        postcode            locality state        long        lat  \
# 0             0                 NaN   NaN    0.000000   0.000000
# 1           200                 ANU   ACT    0.000000   0.000000
# 2           221              BARTON   ACT    0.000000   0.000000
# 3           800              DARWIN    NT  130.836680 -12.458684
# 4           801              DARWIN    NT    0.000000   0.000000
# 5           804               PARAP    NT    0.000000   0.000000
# 6           810               ALAWA    NT  130.866242 -12.381806
# 7           810             BRINKIN    NT  130.866242 -12.381806
# 8           810           CASUARINA    NT  130.866242 -12.381806
# 9           810       COCONUT GROVE    NT  130.866242 -12.381806
# 10          810             JINGILI    NT  130.866242 -12.381806
# 11          810           LEE POINT    NT  130.866242 -12.381806
# 12          810             MILLNER    NT  130.866242 -12.381806
# 13          810                MOIL    NT  130.866242 -12.381806
# 14          810              NAKARA    NT  130.866242 -12.381806
# 15          810          NIGHTCLIFF    NT  130.866242 -12.381806
# 16          810         RAPID CREEK    NT  130.866242 -12.381806
# 17          810                TIWI    NT  130.866242 -12.381806
# 18          810             WAGAMAN    NT  130.866242 -12.381806
# 19          810             WANGURI    NT  130.866242 -12.381806
# 20          811           CASUARINA    NT    0.000000   0.000000
# 21          812               ANULA    NT  130.916098 -12.404778
# 22          812              KARAMA    NT  130.916098 -12.404778
# 23          812             LEANYER    NT  130.916098 -12.404778
# 24          812               MALAK    NT  130.916098 -12.404778
# 25          812             MARRARA    NT  130.916098 -12.404778
# 26          812          NORTHLAKES    NT  130.916098 -12.404778
# 27          812           SANDERSON    NT  130.916098 -12.404778
# 28          812   WOODLEIGH GARDENS    NT  130.916098 -12.404778
# 29          812              WULAGI    NT  130.916098 -12.404778
# ...         ...                 ...   ...         ...        ...
# 16644       880           NHULUNBUY    NT  136.783889 -12.184210
# 16645       881           NHULUNBUY    NT  136.783889 -12.184210
# 16646       886              JABIRU    NT  130.893097 -12.381028
# 16647      8865     SOUTH MELBOURNE   VIC    0.000000   0.000000
# 16648      8873      PORT MELBOURNE   VIC    0.000000   0.000000
# 16649      9000            BRISBANE   QLD    0.000000   0.000000
# 16650      9001            BRISBANE   QLD    0.000000   0.000000
# 16651      9002            BRISBANE   QLD    0.000000   0.000000
# 16652      9003            BRISBANE   QLD    0.000000   0.000000
# 16653      9005            BRISBANE   QLD    0.000000   0.000000
# 16654      9007            BRISBANE   QLD    0.000000   0.000000
# 16655      9008            BRISBANE   QLD    0.000000   0.000000
# 16656      9009            BRISBANE   QLD    0.000000   0.000000
# 16657      9010            BRISBANE   QLD    0.000000   0.000000
# 16658      9013            BRISBANE   QLD    0.000000   0.000000
# 16659      9015            BRISBANE   QLD    0.000000   0.000000
# 16660      9016  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16661      9017  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16662      9018  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16663      9019  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16664      9020            BRISBANE   QLD    0.000000   0.000000
# 16665      9021  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16666      9022  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16667      9023  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16668       906           WINNELLIE    NT  130.882367 -12.426641
# 16669       907           WINNELLIE    NT  130.882367 -12.426641
# 16670      9464        NORTHGATE MC   QLD    0.000000   0.000000
# 16671      9726       GOLD COAST MC   QLD    0.000000   0.000000
# 16672      9728       GOLD COAST MC   QLD    0.000000   0.000000
# 16673      9729       GOLD COAST MC   QLD    0.000000   0.000000
#
#                        dc               type
# 0                     NaN                NaN
# 1                     NaN                NaN
# 2                     NaN                NaN
# 3                     NaN                NaN
# 4                     NaN                NaN
# 5                     NaN                NaN
# 6                     NaN                NaN
# 7                     NaN                NaN
# 8                     NaN                NaN
# 9                     NaN                NaN
# 10                    NaN                NaN
# 11                    NaN                NaN
# 12                    NaN                NaN
# 13                    NaN                NaN
# 14                    NaN                NaN
# 15                    NaN                NaN
# 16                    NaN                NaN
# 17                    NaN                NaN
# 18                    NaN                NaN
# 19                    NaN                NaN
# 20                    NaN                NaN
# 21                    NaN                NaN
# 22                    NaN                NaN
# 23                    NaN                NaN
# 24                    NaN                NaN
# 25                    NaN                NaN
# 26                    NaN                NaN
# 27                    NaN                NaN
# 28                    NaN                NaN
# 29                    NaN                NaN
# ...                   ...                ...
# 16644           NHULUNBUY      Delivery Area
# 16645           NHULUNBUY  Post Office Boxes
# 16646              JABIRU      Delivery Area
# 16647  SOUTH MELBOURNE DC  Post Office Boxes
# 16648  SOUTH MELBOURNE DC  Post Office Boxes
# 16649  CITY DC - BRISBANE                LVR
# 16650  CITY DC - BRISBANE                LVR
# 16651  CITY DC - BRISBANE                LVR
# 16652                 NaN                NaN
# 16653  CITY DC - BRISBANE                LVR
# 16654  CITY DC - BRISBANE                LVR
# 16655  CITY DC - BRISBANE                LVR
# 16656  CITY DC - BRISBANE                LVR
# 16657  CITY DC - BRISBANE                LVR
# 16658  CITY DC - BRISBANE                LVR
# 16659  CITY DC - BRISBANE                LVR
# 16660                 NaN                NaN
# 16661                 NaN                NaN
# 16662                 NaN                NaN
# 16663                 NaN                NaN
# 16664  CITY DC - BRISBANE                LVR
# 16665                 NaN                NaN
# 16666                 NaN                NaN
# 16667                 NaN                NaN
# 16668           DARWIN MC                LVR
# 16669           DARWIN MC                LVR
# 16670                 NaN                NaN
# 16671                 NaN                NaN
# 16672                 NaN                NaN
# 16673                 NaN                NaN
#
# [16674 rows x 7 columns]

# %%
fault_df = pd.read_csv('C:\\Users\\Oliver.Mapeto\\Documents\\03_week_data\\02-getting-to-know-the-tools\\data\\australian_postcodes.csv')

# %%
print(fault_df)
# Out:
#        postcode            locality state        long        lat  \
# 0             0                 NaN   NaN    0.000000   0.000000
# 1           200                 ANU   ACT    0.000000   0.000000
# 2           221              BARTON   ACT    0.000000   0.000000
# 3           800              DARWIN    NT  130.836680 -12.458684
# 4           801              DARWIN    NT    0.000000   0.000000
# 5           804               PARAP    NT    0.000000   0.000000
# 6           810               ALAWA    NT  130.866242 -12.381806
# 7           810             BRINKIN    NT  130.866242 -12.381806
# 8           810           CASUARINA    NT  130.866242 -12.381806
# 9           810       COCONUT GROVE    NT  130.866242 -12.381806
# 10          810             JINGILI    NT  130.866242 -12.381806
# 11          810           LEE POINT    NT  130.866242 -12.381806
# 12          810             MILLNER    NT  130.866242 -12.381806
# 13          810                MOIL    NT  130.866242 -12.381806
# 14          810              NAKARA    NT  130.866242 -12.381806
# 15          810          NIGHTCLIFF    NT  130.866242 -12.381806
# 16          810         RAPID CREEK    NT  130.866242 -12.381806
# 17          810                TIWI    NT  130.866242 -12.381806
# 18          810             WAGAMAN    NT  130.866242 -12.381806
# 19          810             WANGURI    NT  130.866242 -12.381806
# 20          811           CASUARINA    NT    0.000000   0.000000
# 21          812               ANULA    NT  130.916098 -12.404778
# 22          812              KARAMA    NT  130.916098 -12.404778
# 23          812             LEANYER    NT  130.916098 -12.404778
# 24          812               MALAK    NT  130.916098 -12.404778
# 25          812             MARRARA    NT  130.916098 -12.404778
# 26          812          NORTHLAKES    NT  130.916098 -12.404778
# 27          812           SANDERSON    NT  130.916098 -12.404778
# 28          812   WOODLEIGH GARDENS    NT  130.916098 -12.404778
# 29          812              WULAGI    NT  130.916098 -12.404778
# ...         ...                 ...   ...         ...        ...
# 16644       880           NHULUNBUY    NT  136.783889 -12.184210
# 16645       881           NHULUNBUY    NT  136.783889 -12.184210
# 16646       886              JABIRU    NT  130.893097 -12.381028
# 16647      8865     SOUTH MELBOURNE   VIC    0.000000   0.000000
# 16648      8873      PORT MELBOURNE   VIC    0.000000   0.000000
# 16649      9000            BRISBANE   QLD    0.000000   0.000000
# 16650      9001            BRISBANE   QLD    0.000000   0.000000
# 16651      9002            BRISBANE   QLD    0.000000   0.000000
# 16652      9003            BRISBANE   QLD    0.000000   0.000000
# 16653      9005            BRISBANE   QLD    0.000000   0.000000
# 16654      9007            BRISBANE   QLD    0.000000   0.000000
# 16655      9008            BRISBANE   QLD    0.000000   0.000000
# 16656      9009            BRISBANE   QLD    0.000000   0.000000
# 16657      9010            BRISBANE   QLD    0.000000   0.000000
# 16658      9013            BRISBANE   QLD    0.000000   0.000000
# 16659      9015            BRISBANE   QLD    0.000000   0.000000
# 16660      9016  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16661      9017  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16662      9018  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16663      9019  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16664      9020            BRISBANE   QLD    0.000000   0.000000
# 16665      9021  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16666      9022  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16667      9023  BRISBANE GPO BOXES   QLD    0.000000   0.000000
# 16668       906           WINNELLIE    NT  130.882367 -12.426641
# 16669       907           WINNELLIE    NT  130.882367 -12.426641
# 16670      9464        NORTHGATE MC   QLD    0.000000   0.000000
# 16671      9726       GOLD COAST MC   QLD    0.000000   0.000000
# 16672      9728       GOLD COAST MC   QLD    0.000000   0.000000
# 16673      9729       GOLD COAST MC   QLD    0.000000   0.000000
#
#                        dc               type
# 0                     NaN                NaN
# 1                     NaN                NaN
# 2                     NaN                NaN
# 3                     NaN                NaN
# 4                     NaN                NaN
# 5                     NaN                NaN
# 6                     NaN                NaN
# 7                     NaN                NaN
# 8                     NaN                NaN
# 9                     NaN                NaN
# 10                    NaN                NaN
# 11                    NaN                NaN
# 12                    NaN                NaN
# 13                    NaN                NaN
# 14                    NaN                NaN
# 15                    NaN                NaN
# 16                    NaN                NaN
# 17                    NaN                NaN
# 18                    NaN                NaN
# 19                    NaN                NaN
# 20                    NaN                NaN
# 21                    NaN                NaN
# 22                    NaN                NaN
# 23                    NaN                NaN
# 24                    NaN                NaN
# 25                    NaN                NaN
# 26                    NaN                NaN
# 27                    NaN                NaN
# 28                    NaN                NaN
# 29                    NaN                NaN
# ...                   ...                ...
# 16644           NHULUNBUY      Delivery Area
# 16645           NHULUNBUY  Post Office Boxes
# 16646              JABIRU      Delivery Area
# 16647  SOUTH MELBOURNE DC  Post Office Boxes
# 16648  SOUTH MELBOURNE DC  Post Office Boxes
# 16649  CITY DC - BRISBANE                LVR
# 16650  CITY DC - BRISBANE                LVR
# 16651  CITY DC - BRISBANE                LVR
# 16652                 NaN                NaN
# 16653  CITY DC - BRISBANE                LVR
# 16654  CITY DC - BRISBANE                LVR
# 16655  CITY DC - BRISBANE                LVR
# 16656  CITY DC - BRISBANE                LVR
# 16657  CITY DC - BRISBANE                LVR
# 16658  CITY DC - BRISBANE                LVR
# 16659  CITY DC - BRISBANE                LVR
# 16660                 NaN                NaN
# 16661                 NaN                NaN
# 16662                 NaN                NaN
# 16663                 NaN                NaN
# 16664  CITY DC - BRISBANE                LVR
# 16665                 NaN                NaN
# 16666                 NaN                NaN
# 16667                 NaN                NaN
# 16668           DARWIN MC                LVR
# 16669           DARWIN MC                LVR
# 16670                 NaN                NaN
# 16671                 NaN                NaN
# 16672                 NaN                NaN
# 16673                 NaN                NaN
#
# [16674 rows x 7 columns]

# %% [markdown]
# How will you find incorrect values in your data? Can you write a small function to test these? For more details on Python functions you can work through [this little tutorial on DataCamp](https://www.datacamp.com/community/tutorials/functions-python-tutorial)
#
# Also take a look at the [`apply`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.apply.html) method for more tricky data munging that has to be carried out record-by-record
#
# Try writing a small function to apply to one of the columns in your dataframe - here's a toy example to get you started: your function could look something like:
#
# ```python
# import random
# import pandas
#
# # Make some bogus data - see random_data.py for defns
# from random_data import random_dataframe
#
# df = random_dataframe(10)
#
# # Define our bogus function
# def random_replacement(record):
#     "Some of column 'a', some of column 'b'"
#     return random.sample([record.a, record.b], 1)[0]
#
# # Apply function once per record
# df.apply(random_replacement, axis='columns')
# ```
#
# Work out how to apply a function once per column as well.

# %% [markdown]
# ### Step 3: Tidy my data
#
# Work through the 'tidy data checklist' and make sure your data has been tidied!
#
# 1. Each variable you measure should be in one column.
# 2. Each different observation of that variable should be in a different row.
# 3. There should be one table for each "kind" of variable.
# 4. If you have multiple tables, they should include a column in the table that allows them to be linked.
#
# This is a good overview: http://www.jeannicholashould.com/tidy-data-in-python.html
#
# If your data is already tidy, try downloading the data from that tutorial and working through it instead.

# %% [markdown]
# Once you're done with this, copy your code from steps 2 and 3 over to a Python script for easier sharing. This is an example of an extract-transform-load workflow that you could share with your IT department to run automatically when your org collects more data that is similar to this.
